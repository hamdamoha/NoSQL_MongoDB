# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)
mongo.list_database_names()
# Out:
# ['admin', 'config', 'local', 'met', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
food_db = mongo['uk_food']

# %%
# review the collections in our database
mongo.list_database_names()
# Out:
# ['admin', 'config', 'local', 'met', 'travel_db', 'uk_food']

# %%
print(food_db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments_collection = food_db['establishments']
print(type(establishments_collection))
# Out:
# <class 'pymongo.collection.Collection'>

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Count the number of total establishments
total_est = establishments_collection.count_documents({})
print(total_est)

# Find the establishments with a hygiene score of 20
# query = {'scores': {'Hygiene' : 20}}
query = {'scores.Hygiene' : 20}
# query = {}
results = establishments_collection.find(query)


#for i in list(results):
#     hscore = i['scores']['Hygiene']
#     if hscore and hscore > 15:
#         print(type(hscore)) 

# # Use count_documents to display the number of documents in the result
establishments_collection.count_documents(query)

# # Display the first document in the results using pprint
# Out:
# 38788
# 41

# %%
result_list = list(results)
print(len(result_list))
# Out:
# 41

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(result_list)

# Display the number of rows in the DataFrame
df.shape

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d1bb2b3ee304cb74d44ad0   110681                  0
# 1  63d1bb2b3ee304cb74d44e46   612039                  0
# 2  63d1bb2b3ee304cb74d4514f   730933                  0
# 3  63d1bb2b3ee304cb74d4533f   172735                  0
# 4  63d1bb2b3ee304cb74d4534f   172953                  0
# 5  63d1bb2b3ee304cb74d45cf4   512854                  0
# 6  63d1bb2b3ee304cb74d45f0f  1537089                  0
# 7  63d1bb2c3ee304cb74d4743c   155648                  0
# 8  63d1bb2c3ee304cb74d4787f  1012883                  0
# 9  63d1bb2c3ee304cb74d48091   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'London.RatingValue': {'$gte': 4}}
results = establishments_collection.find(query)
# Use count_documents to display the number of documents in the result
establishments_collection.count_documents(query)
# Display the first document in the results using pprint
# pprint(next(results))
# Out:
# 0

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
result_df.shape
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
PENANG_LAT = 51.49014200
PENANG_LON = 0.08384000
TOL_DEG = 0.01

tol_lat_inf = PENANG_LAT - TOL_DEG
tol_lat_sup = PENANG_LAT + TOL_DEG

tol_lon_inf = PENANG_LON - TOL_DEG
tol_lon_sup = PENANG_LON + TOL_DEG



# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {
  'RatingValue': '5',
         'geocode.longitude':{'$gte':tol_lon_inf, '$lte':tol_lon_sup},
        'geocode.latitude':{'$gte':tol_lat_inf, '$lte':tol_lat_sup}}

sort = [('HygieneScore', 1)]

results_loc = establishments_collection.find(query).sort(sort).limit(5)

for result in results:
    pprint(result)

# %%
# Convert result to Pandas DataFrame
results_df = pd.DataFrame(results_loc)
results_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d1bb2c3ee304cb74d4a30b  1380578                  0
# 1  63d1bb2c3ee304cb74d4a33e   695241                  0
# 2  63d1bb2c3ee304cb74d4a2d1  1069652                  0
# 3  63d1bb2c3ee304cb74d4a2fa   695223                  0
# 4  63d1bb2c3ee304cb74d4a32c   694609                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0                    14425  Howe and Co Fish and Chips - Van 17
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 3             PI/000178842                              Iceland
# 4             PI/000116619                            Volunteer
#
#                             BusinessType  BusinessTypeID  \
# 0                         Mobile caterer            7846
# 1                        Caring Premises               5
# 2                Restaurant/Cafe/Canteen               1
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

match_query = {'$match': {'scores.Hygiene': 0}}

group_query = {'$group': {'_id': '$LocalAuthorityName', 'count': { '$sum': 1 }}}

sort_values = {'$sort': { 'count': -1 }}

pipeline = [match_query, group_query, sort_values]

results = list(establishments_collection.aggregate(pipeline))

# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
# Display the first 10 rows of the DataFrame
print("Rows in DataFrame: ", len(result_df))
result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
